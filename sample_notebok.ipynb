# %% [markdown]
# ##ibrahem Nofal

# %%
import pandas as pn
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Problem defintion

# %% [markdown]
# # Data

# %%
df=pn.read_csv("heart-disease.csv")

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.target.value_counts().plot(kind="bar")

# %% [markdown]
# ![](6-step-ml-framework.png)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.iloc[2:9,1:5]
# Out:
#    sex  cp  trestbps  chol
# 2    0   1       130   204
# 3    1   1       120   236
# 4    0   0       120   354
# 5    1   0       140   192
# 6    0   1       140   294
# 7    1   1       120   263
# 8    1   2       172   199

# %%
import pandas as pd

# %%
df2=pd.read_csv("air_quality_no2.csv",index_col=0, parse_dates=True)
df2.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %%
df2["station_paris"].plot()

# %%
df2.plot.scatter(x="station_london",y="station_paris",alpha=0.5)

# %%
axs = df2.plot.area(figsize=(10, 4), subplots=True)

# %% [markdown]
# # fig, axs = plt.subplots(figsize=(12, 4))        # Create an empty matplotlib Figure and Axes
# air_quality.plot.area(ax=axs)                   # Use pandas to put the area plot on the prepared Figure/Axes
# axs.set_ylabel("NO$_2$ concentration")          # Do any matplotlib customization you like
# fig.savefig("no2_concentrations.png")           # Save the Figure/Axes using the existing matplotlib method.

# %%
fig, axs = plt.subplots(figsize=(12, 4));
df2.plot.area(ax=axs)
axs.set_ylabel("NO$_2$ concentration");
fig.savefig("no2_concentrations.png")

# %%
df2["london_mg_per_cubic"]=df2["station_london"] * 1.85
df2["station_london"]
# Out:
# datetime
# 2019-05-07 02:00:00    23.0
# 2019-05-07 03:00:00    19.0
# 2019-05-07 04:00:00    19.0
# 2019-05-07 05:00:00    16.0
# 2019-05-07 06:00:00     NaN
#                        ...
# 2019-06-20 22:00:00     NaN
# 2019-06-20 23:00:00     NaN
# 2019-06-21 00:00:00     NaN
# 2019-06-21 01:00:00     NaN
# 2019-06-21 02:00:00     NaN
# Name: station_london, Length: 1035, dtype: float64

# %%
df2["ratio_paris_antwerp"]=df2["station_paris"] / df2["station_antwerp"]
df2.head()
df2.dropna()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-08 03:00:00             23.0           19.6            20.0
# 2019-05-08 04:00:00             20.5           15.3            20.0
# 2019-05-09 03:00:00             20.0           10.6            31.0
# ...                              ...            ...             ...
# 2019-06-17 06:00:00             39.5           45.7            11.0
# 2019-06-17 07:00:00             42.5           44.8            12.0
# 2019-06-17 08:00:00             43.5           52.3            13.0
# 2019-06-17 09:00:00             45.0           54.4            13.0
# 2019-06-17 10:00:00             41.0           51.6            11.0
#
#                      london_mg_per_cubic  ratio_paris_antwerp
# datetime
# 2019-05-07 03:00:00                35.15             0.495050
# ...

# %%
df2_renamed=df2.rename(columns={"station_antwerp": "BETR801",
                                "station_paris": "FR04014",
                                "station_london": "London Westminster"})

# %%
df2_renamed
# Out:
#                      BETR801  FR04014  London Westminster  \
# datetime
# 2019-05-07 02:00:00      NaN      NaN                23.0
# 2019-05-07 03:00:00     50.5     25.0                19.0
# 2019-05-07 04:00:00     45.0     27.7                19.0
# 2019-05-07 05:00:00      NaN     50.4                16.0
# 2019-05-07 06:00:00      NaN     61.9                 NaN
# ...                      ...      ...                 ...
# 2019-06-20 22:00:00      NaN     21.4                 NaN
# 2019-06-20 23:00:00      NaN     24.9                 NaN
# 2019-06-21 00:00:00      NaN     26.5                 NaN
# 2019-06-21 01:00:00      NaN     21.8                 NaN
# 2019-06-21 02:00:00      NaN     20.0                 NaN
#
#                      london_mg_per_cubic  ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00                42.55                  NaN
# 2019-05-07 03:00:00                35.15             0.495050
# ...

# %%
titanic=pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic["Age"].mean()
# Out:
# 29.69911764705882

# %%
titanic[["Age","Fare"]].median()
# Out:
# Age     28.0000
# Fare    14.4542
# dtype: float64

# %%
titanic.agg({'Age': ['min', 'max', 'median', 'skew'],'Fare': ['min', 'max', 'median', 'mean']})
# Out:
#               Age        Fare
# max     80.000000  512.329200
# mean          NaN   32.204208
# median  28.000000   14.454200
# min      0.420000    0.000000
# skew     0.389108         NaN

# %%
titanic[["Sex", "Age"]].groupby("Sex").mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
titanic.groupby("Sex").mean()
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
titanic.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
titanic.groupby(["Sex", "Pclass"])["Fare"].mean()
# Out:
# Sex     Pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: Fare, dtype: float64

# %%
titanic["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
titanic.groupby(["Sex", "Pclass"])["Fare"].mean()
# Out:
# Sex     Pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: Fare, dtype: float64

# %%
titanic.groupby(["Sex","Embarked"])["Fare"].mean()
# Out:
# Sex     Embarked
# female  C           75.169805
#         Q           12.634958
#         S           38.740929
# male    C           48.262109
#         Q           13.838922
#         S           21.711996
# Name: Fare, dtype: float64

# %%
titanic.sort_values(by="Embarked").head()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 258          259         1       1              Ward, Miss. Anna  female
# 125          126         1       3  Nicola-Yarred, Master. Elias    male
# 354          355         0       3             Yousif, Mr. Wazli    male
# 352          353         0       3            Elias, Mr. Tannous    male
# 128          129         1       3             Peter, Miss. Anna  female
#
#       Age  SibSp  Parch    Ticket      Fare  Cabin Embarked
# 258  35.0      0      0  PC 17755  512.3292    NaN        C
# 125  12.0      1      0      2651   11.2417    NaN        C
# 354   NaN      0      0      2647    7.2250    NaN        C
# 352  15.0      1      1      2695    7.2292    NaN        C
# 128   NaN      1      1      2668   22.3583  F E69        C

# %%
titanic.sort_values(by=['Pclass', 'Age'], ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass                       Name     Sex   Age  \
# 851          852         0       3        Svensson, Mr. Johan    male  74.0
# 116          117         0       3       Connors, Mr. Patrick    male  70.5
# 280          281         0       3           Duane, Mr. Frank    male  65.0
# 483          484         1       3     Turkula, Mrs. (Hedwig)  female  63.0
# 326          327         0       3  Nysveen, Mr. Johan Hansen    male  61.0
#
#      SibSp  Parch  Ticket    Fare Cabin Embarked
# 851      0      0  347060  7.7750   NaN        S
# 116      0      0  370369  7.7500   NaN        Q
# 280      0      0  336439  7.7500   NaN        Q
# 483      0      0    4134  9.5875   NaN        S
# 326      0      0  345364  6.2375   NaN        S

# %%
df3=pd.read_csv("air_quality_long.csv")
df3.head()
# Out:
#         city country                   date.utc location parameter  value  \
# 0  Antwerpen      BE  2019-06-18 06:00:00+00:00  BETR801      pm25   18.0
# 1  Antwerpen      BE  2019-06-17 08:00:00+00:00  BETR801      pm25    6.5
# 2  Antwerpen      BE  2019-06-17 07:00:00+00:00  BETR801      pm25   18.5
# 3  Antwerpen      BE  2019-06-17 06:00:00+00:00  BETR801      pm25   16.0
# 4  Antwerpen      BE  2019-06-17 05:00:00+00:00  BETR801      pm25    7.5
#
#     unit
# 0  µg/m³
# 1  µg/m³
# 2  µg/m³
# 3  µg/m³
# 4  µg/m³

# %%
# change the data inside parameter
no2=df3[df3["parameter"]=="no2"]
no2_subset=no2.sort_index().groupby(['location']).head(2)
no2_subset
# Out:
#            city country                   date.utc            location  \
# 1825      Paris      FR  2019-06-21 00:00:00+00:00             FR04014
# 1826      Paris      FR  2019-06-20 23:00:00+00:00             FR04014
# 3501  Antwerpen      BE  2019-06-17 08:00:00+00:00             BETR801
# 3502  Antwerpen      BE  2019-06-17 07:00:00+00:00             BETR801
# 3664     London      GB  2019-06-17 11:00:00+00:00  London Westminster
# 3665     London      GB  2019-06-17 10:00:00+00:00  London Westminster
#
#      parameter  value   unit
# 1825       no2   20.0  µg/m³
# 1826       no2   21.8  µg/m³
# 3501       no2   41.0  µg/m³
# 3502       no2   45.0  µg/m³
# 3664       no2   11.0  µg/m³
# 3665       no2   11.0  µg/m³

# %%
#values for the three stations as separate columns next to each other
no2_subset.pivot(columns="location", values="value")
# Out:
# location  BETR801  FR04014  London Westminster
# 1825          NaN     20.0                 NaN
# 1826          NaN     21.8                 NaN
# 3501         41.0      NaN                 NaN
# 3502         45.0      NaN                 NaN
# 3664          NaN      NaN                11.0
# 3665          NaN      NaN                11.0

# %%
no2.pivot(columns="location", values="value").plot()

# %%
#I want the mean concentrations for 𝑁𝑂2 and 𝑃𝑀2.5 in each of the stations in table form
df3.pivot_table(values="value", index="location",columns="parameter", aggfunc="mean")
# Out:
# parameter                 no2       pm25
# location
# BETR801             26.950920  23.169492
# FR04014             29.374284        NaN
# London Westminster  29.740050  13.443568

# %%
no2_pivoted = no2.pivot(columns="location", values="value").reset_index()
no2_pivoted.head()
# Out:
# location  index  BETR801  FR04014  London Westminster
# 0          1825      NaN     20.0                 NaN
# 1          1826      NaN     21.8                 NaN
# 2          1827      NaN     26.5                 NaN
# 3          1828      NaN     24.9                 NaN
# 4          1829      NaN     21.4                 NaN

# %%
no_2 = no2_subset.melt(id_vars="date.utc")

no_2.head()
# Out:
#                     date.utc variable      value
# 0  2019-06-21 00:00:00+00:00     city      Paris
# 1  2019-06-20 23:00:00+00:00     city      Paris
# 2  2019-06-17 08:00:00+00:00     city  Antwerpen
# 3  2019-06-17 07:00:00+00:00     city  Antwerpen
# 4  2019-06-17 11:00:00+00:00     city     London

# %%
no_2.rename(columns={"date.utc": "Datetime"})
# Out:
#                      Datetime   variable               value
# 0   2019-06-21 00:00:00+00:00       city               Paris
# 1   2019-06-20 23:00:00+00:00       city               Paris
# 2   2019-06-17 08:00:00+00:00       city           Antwerpen
# 3   2019-06-17 07:00:00+00:00       city           Antwerpen
# 4   2019-06-17 11:00:00+00:00       city              London
# 5   2019-06-17 10:00:00+00:00       city              London
# 6   2019-06-21 00:00:00+00:00    country                  FR
# 7   2019-06-20 23:00:00+00:00    country                  FR
# 8   2019-06-17 08:00:00+00:00    country                  BE
# 9   2019-06-17 07:00:00+00:00    country                  BE
# 10  2019-06-17 11:00:00+00:00    country                  GB
# 11  2019-06-17 10:00:00+00:00    country                  GB
# 12  2019-06-21 00:00:00+00:00   location             FR04014
# 13  2019-06-20 23:00:00+00:00   location             FR04014
# ...
